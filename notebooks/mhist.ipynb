# %%
from PIL import Image
import numpy as np

# %%
im = Image.open("../data/mhist/images/MHIST_aaa.png")

# %%
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=224x224>

# %%
np.asarray(im).shape
# Out:
# (224, 224, 3)

# %% [markdown]
# All images have 3 channels? Yes (224, 224, 3)

# %%
import os

all_images_path = [
    f"../data/mhist/images/{img_name}"
    for img_name in os.listdir("../data/mhist/images")
    if img_name.endswith("png")
]

# %%
shapes = set()

for impath in all_images_path:
    im = np.asarray(Image.open(impath))
    shapes.add(im.shape)

# %%
shapes
# Out:
# {(224, 224, 3)}
